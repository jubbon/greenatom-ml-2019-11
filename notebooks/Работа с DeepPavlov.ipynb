# %%
import json
import requests

# %%
data = dict(
    x=list((
        "В МФТИ можно добраться на электричке",
        "Поедем на поезде до Москвы, Куликов купит билеты, будем презентовать проект",
        "Мне не нравится прогресс в движении проекта, сотрудники плохо работают",
        "Иванов просто отличный сотрудник",
        "Наш начальник - идиот",
        "Сам ты козел",
        "Вы все молодцы, продолжайте в том же духе",
        "Напоминаю, завтра состоится планерка по Аккорду"
    ))
)
r = requests.post('http://127.0.0.1:5005/model', data=json.dumps(data))
r.text
# Out:
# '[[["В","МФТИ","можно","добраться","на","электричке"],["O","B-ORG","O","O","O","O"]],[["Поедем","на","поезде","до","Москвы",",","Куликов","купит","билеты",",","будем","презентовать","проект"],["O","O","O","O","B-LOC","O","B-PER","O","O","O","O","O","O"]],[["Мне","не","нравится","прогресс","в","движении","проекта",",","сотрудники","плохо","работают"],["O","O","O","O","O","O","O","O","O","O","O"]],[["Иванов","просто","отличный","сотрудник"],["B-PER","O","O","O"]],[["Наш","начальник","-","идиот"],["O","O","O","O"]],[["Сам","ты","козел"],["O","O","O"]],[["Вы","все","молодцы",",","продолжайте","в","том","же","духе"],["O","O","O","O","O","O","O","O","O"]],[["Напоминаю",",","завтра","состоится","планерка","по","Аккорду"],["O","O","O","O","O","O","B-LOC"]]]'
